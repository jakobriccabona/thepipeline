# %%
import pandas as pd
import glob

# Ordnerpfad, in dem sich die .weight-Dateien befinden
folder_path = "./"  # Passe den Pfad an

# Alle .weight-Dateien im Ordner sammeln
weight_files = glob.glob(folder_path + "*.weights")

# Dictionary, um Ergebnisse zu sammeln
data = {}

# Dateien einlesen und Daten sammeln
for file in weight_files:
    print(f"Verarbeite Datei: {file}")
    try:
        # Lies die Datei ein und überspringe Kommentarzeilen
        df = pd.read_csv(file, delim_whitespace=True, comment='#', names=["POSNUM", "RESIDUETYPE", "WEIGHT"])
        
        for _, row in df.iterrows():
            key = (row["POSNUM"], row["RESIDUETYPE"])  # Kombination aus POSNUM und RESIDUETYPE
            weight = float(row["WEIGHT"])  # Gewicht extrahieren
            
            if key not in data:
                data[key] = []
            data[key].append(weight)
    except Exception as e:
        print(f"Fehler beim Verarbeiten der Datei {file}: {e}")

# Durchschnitt der Weights berechnen
result = []
for key, weights in data.items():
    avg_weight = sum(weights) / len(weights)
    result.append({
        "POSNUM": key[0],
        "RESIDUETYPE": key[1],
        "WEIGHT": avg_weight
    })

# Ergebnisse in ein DataFrame umwandeln
result_df = pd.DataFrame(result)

# Ergebnisse in eine neue Datei speichern
output_path = "./mpnn_probs.weights"  # Passe den Speicherpfad an
with open(output_path, "w") as f:
    f.write("#POSNUM RESIDUETYPE WEIGHT\n")  # Header hinzufügen
    result_df.to_csv(f, sep=' ', index=False, header=False)

print(f"Die durchschnittlichen Gewichte wurden in '{output_path}' gespeichert.")
# Out:
# Verarbeite Datei: ./20_763_mpnn_probs.weights
# Verarbeite Datei: ./0_313_mpnn_probs.weights
# Verarbeite Datei: ./20_853_mpnn_probs.weights
# Verarbeite Datei: ./20_140_mpnn_probs.weights
# Verarbeite Datei: ./10_30_mpnn_probs.weights
# Verarbeite Datei: ./9_655_mpnn_probs.weights
# Verarbeite Datei: ./13_905_mpnn_probs.weights
# Verarbeite Datei: ./22_83_mpnn_probs.weights
# Verarbeite Datei: ./20_25_mpnn_probs.weights
# Verarbeite Datei: ./16_786_mpnn_probs.weights
# Verarbeite Datei: ./20_104_mpnn_probs.weights
# Verarbeite Datei: ./14_589_mpnn_probs.weights
# Verarbeite Datei: ./15_150_mpnn_probs.weights
# Verarbeite Datei: ./10_846_mpnn_probs.weights
# Verarbeite Datei: ./14_478_mpnn_probs.weights
# Verarbeite Datei: ./22_6_mpnn_probs.weights
# Verarbeite Datei: ./9_435_mpnn_probs.weights
# Verarbeite Datei: ./9_608_mpnn_probs.weights
# Verarbeite Datei: ./15_627_mpnn_probs.weights
# Verarbeite Datei: ./16_287_mpnn_probs.weights
# Verarbeite Datei: ./0_156_mpnn_probs.weights
# Verarbeite Datei: ./10_64_mpnn_probs.weights
# Verarbeite Datei: ./13_798_mpnn_probs.weights
# Verarbeite Datei: ./5_771_mpnn_probs.weights
# Verarbeite Datei: ./14_645_mpnn_probs.weights
# Verarbeite Datei: ./20_387_mpnn_probs.weights
# Verarbeite Datei: ./0_621_mpnn_probs.weights
# Verarbeite Datei: ./10_92_mpnn_probs.weights
# Verarbeite Datei: ./5_725_mpnn_probs.weights
# Verarbeite Datei: ./10_584_mpnn_probs.weights
# Verarbeite Datei: ./14_364_mpnn_probs.weights
# Verarbeite Datei: ./20_43_mpnn_probs.weights
# Verarbeite Datei: ./14_929_mpnn_probs.weights
# Verarbeite Datei: ./15_228_mpnn_probs.weights
# Verarbeite Datei: ./9_918_mpnn_probs.weights
# Verarbeite Datei: ./14_503_mpnn_probs.weights
# Verarbeite Datei: ./13_115_mpnn_probs.weights
# Verarbeite Datei: ./16_989_mpnn_probs.weights
# Verarbeite Datei: ./15_317_mpnn_probs.weights
# Verarbeite Datei: ./20_198_mpnn_probs.weights
# Verarbeite Datei: ./5_220_mpnn_probs.weights
# Verarbeite Datei: ./14_737_mpnn_probs.weights
# Verarbeite Datei: ./15_817_mpnn_probs.weights
# Verarbeite Datei: ./10_646_mpnn_probs.weights
# Verarbeite Datei: ./16_645_mpnn_probs.weights
# Verarbeite Datei: ./0_887_mpnn_probs.weights
# Verarbeite Datei: ./13_969_mpnn_probs.weights
# Verarbeite Datei: ./0_985_mpnn_probs.weights
# Verarbeite Datei: ./14_214_mpnn_probs.weights
# Verarbeite Datei: ./20_936_mpnn_probs.weights
# Verarbeite Datei: ./16_209_mpnn_probs.weights
# Verarbeite Datei: ./15_9_mpnn_probs.weights
# Verarbeite Datei: ./10_556_mpnn_probs.weights
# Verarbeite Datei: ./22_217_mpnn_probs.weights
# Verarbeite Datei: ./22_1000_mpnn_probs.weights
# Verarbeite Datei: ./20_908_mpnn_probs.weights
# Verarbeite Datei: ./16_828_mpnn_probs.weights
# Verarbeite Datei: ./9_172_mpnn_probs.weights
# Verarbeite Datei: ./15_735_mpnn_probs.weights
# Verarbeite Datei: ./5_85_mpnn_probs.weights
# Verarbeite Datei: ./14_266_mpnn_probs.weights
# Verarbeite Datei: ./5_625_mpnn_probs.weights
# Verarbeite Datei: ./14_926_mpnn_probs.weights
# Verarbeite Datei: ./20_303_mpnn_probs.weights
# Verarbeite Datei: ./14_101_mpnn_probs.weights
# Verarbeite Datei: ./16_109_mpnn_probs.weights
# Verarbeite Datei: ./9_397_mpnn_probs.weights
# Verarbeite Datei: ./0_766_mpnn_probs.weights
# Verarbeite Datei: ./9_9_mpnn_probs.weights
# Verarbeite Datei: ./13_502_mpnn_probs.weights
# Verarbeite Datei: ./13_753_mpnn_probs.weights
# Verarbeite Datei: ./0_14_mpnn_probs.weights
# Verarbeite Datei: ./13_775_mpnn_probs.weights
# Verarbeite Datei: ./16_730_mpnn_probs.weights
# Verarbeite Datei: ./10_916_mpnn_probs.weights
# Verarbeite Datei: ./15_434_mpnn_probs.weights
# Verarbeite Datei: ./15_750_mpnn_probs.weights
# Verarbeite Datei: ./16_16_mpnn_probs.weights
# Verarbeite Datei: ./16_751_mpnn_probs.weights
# Verarbeite Datei: ./10_380_mpnn_probs.weights
# Verarbeite Datei: ./5_877_mpnn_probs.weights
# Verarbeite Datei: ./16_143_mpnn_probs.weights
# Verarbeite Datei: ./14_615_mpnn_probs.weights
# Verarbeite Datei: ./13_144_mpnn_probs.weights
# Verarbeite Datei: ./15_495_mpnn_probs.weights
# Verarbeite Datei: ./0_545_mpnn_probs.weights
# Verarbeite Datei: ./9_449_mpnn_probs.weights
# Verarbeite Datei: ./13_225_mpnn_probs.weights
# Verarbeite Datei: ./14_38_mpnn_probs.weights
# Verarbeite Datei: ./20_142_mpnn_probs.weights
# Verarbeite Datei: ./15_449_mpnn_probs.weights
# Verarbeite Datei: ./14_227_mpnn_probs.weights
# Verarbeite Datei: ./22_586_mpnn_probs.weights
# Verarbeite Datei: ./20_175_mpnn_probs.weights
# Verarbeite Datei: ./16_152_mpnn_probs.weights
# Verarbeite Datei: ./20_894_mpnn_probs.weights
# Verarbeite Datei: ./0_459_mpnn_probs.weights
# Verarbeite Datei: ./20_356_mpnn_probs.weights
# Verarbeite Datei: ./10_818_mpnn_probs.weights
# Verarbeite Datei: ./20_316_mpnn_probs.weights
# Verarbeite Datei: ./10_379_mpnn_probs.weights
# Verarbeite Datei: ./20_402_mpnn_probs.weights
# Verarbeite Datei: ./14_343_mpnn_probs.weights
# Verarbeite Datei: ./16_159_mpnn_probs.weights
# Verarbeite Datei: ./10_638_mpnn_probs.weights
# Verarbeite Datei: ./22_511_mpnn_probs.weights
# Verarbeite Datei: ./5_784_mpnn_probs.weights
# Verarbeite Datei: ./14_558_mpnn_probs.weights
# Verarbeite Datei: ./20_119_mpnn_probs.weights
# Verarbeite Datei: ./5_452_mpnn_probs.weights
# Verarbeite Datei: ./9_62_mpnn_probs.weights
# Verarbeite Datei: ./5_524_mpnn_probs.weights
# Verarbeite Datei: ./16_410_mpnn_probs.weights
# Verarbeite Datei: ./10_66_mpnn_probs.weights
# Verarbeite Datei: ./10_588_mpnn_probs.weights
# Verarbeite Datei: ./16_875_mpnn_probs.weights
# Verarbeite Datei: ./20_761_mpnn_probs.weights
# Verarbeite Datei: ./13_921_mpnn_probs.weights
# Verarbeite Datei: ./0_993_mpnn_probs.weights
# Verarbeite Datei: ./0_783_mpnn_probs.weights
# Verarbeite Datei: ./9_829_mpnn_probs.weights
# Verarbeite Datei: ./13_808_mpnn_probs.weights
# Verarbeite Datei: ./15_301_mpnn_probs.weights
# Verarbeite Datei: ./22_732_mpnn_probs.weights
# Verarbeite Datei: ./0_430_mpnn_probs.weights
# Verarbeite Datei: ./5_145_mpnn_probs.weights
# Verarbeite Datei: ./16_316_mpnn_probs.weights
# Verarbeite Datei: ./9_297_mpnn_probs.weights
# Verarbeite Datei: ./13_408_mpnn_probs.weights
# Verarbeite Datei: ./16_203_mpnn_probs.weights
# Verarbeite Datei: ./22_650_mpnn_probs.weights
# Verarbeite Datei: ./22_243_mpnn_probs.weights
# Verarbeite Datei: ./14_600_mpnn_probs.weights
# Verarbeite Datei: ./13_113_mpnn_probs.weights
# Verarbeite Datei: ./22_518_mpnn_probs.weights
# Verarbeite Datei: ./22_934_mpnn_probs.weights
# Verarbeite Datei: ./16_668_mpnn_probs.weights
# Verarbeite Datei: ./5_892_mpnn_probs.weights
# Verarbeite Datei: ./20_120_mpnn_probs.weights
# Verarbeite Datei: ./5_804_mpnn_probs.weights
# Verarbeite Datei: ./15_54_mpnn_probs.weights
# Verarbeite Datei: ./14_27_mpnn_probs.weights
# Verarbeite Datei: ./5_19_mpnn_probs.weights
# Verarbeite Datei: ./10_470_mpnn_probs.weights
# Verarbeite Datei: ./5_779_mpnn_probs.weights
# Verarbeite Datei: ./20_242_mpnn_probs.weights
# Verarbeite Datei: ./5_485_mpnn_probs.weights
# Verarbeite Datei: ./14_160_mpnn_probs.weights
# Verarbeite Datei: ./13_783_mpnn_probs.weights
# Verarbeite Datei: ./5_556_mpnn_probs.weights
# Verarbeite Datei: ./13_992_mpnn_probs.weights
# Verarbeite Datei: ./10_529_mpnn_probs.weights
# Verarbeite Datei: ./22_447_mpnn_probs.weights
# Verarbeite Datei: ./0_689_mpnn_probs.weights
# Verarbeite Datei: ./15_739_mpnn_probs.weights
# Verarbeite Datei: ./14_496_mpnn_probs.weights
# Verarbeite Datei: ./0_114_mpnn_probs.weights
# Verarbeite Datei: ./5_583_mpnn_probs.weights
# Verarbeite Datei: ./15_359_mpnn_probs.weights
# Verarbeite Datei: ./13_28_mpnn_probs.weights
# Verarbeite Datei: ./5_489_mpnn_probs.weights
# Verarbeite Datei: ./16_99_mpnn_probs.weights
# Verarbeite Datei: ./14_21_mpnn_probs.weights
# Verarbeite Datei: ./5_863_mpnn_probs.weights
# Verarbeite Datei: ./22_368_mpnn_probs.weights
# Verarbeite Datei: ./20_114_mpnn_probs.weights
# Verarbeite Datei: ./9_385_mpnn_probs.weights
# Verarbeite Datei: ./0_653_mpnn_probs.weights
# Verarbeite Datei: ./13_829_mpnn_probs.weights
# Verarbeite Datei: ./5_931_mpnn_probs.weights
# Verarbeite Datei: ./16_378_mpnn_probs.weights
# Verarbeite Datei: ./14_975_mpnn_probs.weights
# Verarbeite Datei: ./14_279_mpnn_probs.weights
# Verarbeite Datei: ./5_858_mpnn_probs.weights
# Verarbeite Datei: ./22_13_mpnn_probs.weights
# Verarbeite Datei: ./9_317_mpnn_probs.weights
# Verarbeite Datei: ./16_889_mpnn_probs.weights
# Verarbeite Datei: ./9_953_mpnn_probs.weights
# Verarbeite Datei: ./13_209_mpnn_probs.weights
# Verarbeite Datei: ./0_734_mpnn_probs.weights
# Verarbeite Datei: ./10_980_mpnn_probs.weights
# Verarbeite Datei: ./14_542_mpnn_probs.weights
# Verarbeite Datei: ./22_809_mpnn_probs.weights
# Verarbeite Datei: ./22_718_mpnn_probs.weights
# Verarbeite Datei: ./20_352_mpnn_probs.weights
# Verarbeite Datei: ./10_458_mpnn_probs.weights
# Verarbeite Datei: ./20_359_mpnn_probs.weights
# Verarbeite Datei: ./15_607_mpnn_probs.weights
# Verarbeite Datei: ./5_159_mpnn_probs.weights
# Verarbeite Datei: ./22_4_mpnn_probs.weights
# Verarbeite Datei: ./22_119_mpnn_probs.weights
# Verarbeite Datei: ./9_415_mpnn_probs.weights
# Verarbeite Datei: ./9_126_mpnn_probs.weights
# Verarbeite Datei: ./10_711_mpnn_probs.weights
# Verarbeite Datei: ./9_838_mpnn_probs.weights
# Verarbeite Datei: ./14_823_mpnn_probs.weights
# Verarbeite Datei: ./22_793_mpnn_probs.weights
# Verarbeite Datei: ./14_749_mpnn_probs.weights
# Verarbeite Datei: ./9_946_mpnn_probs.weights
# Verarbeite Datei: ./0_860_mpnn_probs.weights
# Verarbeite Datei: ./0_478_mpnn_probs.weights
# Verarbeite Datei: ./20_154_mpnn_probs.weights
# Verarbeite Datei: ./15_675_mpnn_probs.weights
# Verarbeite Datei: ./10_461_mpnn_probs.weights
# Verarbeite Datei: ./9_881_mpnn_probs.weights
# Verarbeite Datei: ./9_425_mpnn_probs.weights
# Verarbeite Datei: ./15_805_mpnn_probs.weights
# Verarbeite Datei: ./14_379_mpnn_probs.weights
# Verarbeite Datei: ./10_502_mpnn_probs.weights
# Verarbeite Datei: ./0_591_mpnn_probs.weights
# Verarbeite Datei: ./14_964_mpnn_probs.weights
# Verarbeite Datei: ./22_87_mpnn_probs.weights
# Verarbeite Datei: ./13_546_mpnn_probs.weights
# Verarbeite Datei: ./14_927_mpnn_probs.weights
# Verarbeite Datei: ./10_683_mpnn_probs.weights
# Verarbeite Datei: ./15_469_mpnn_probs.weights
# Verarbeite Datei: ./20_298_mpnn_probs.weights
# Verarbeite Datei: ./20_993_mpnn_probs.weights
# Verarbeite Datei: ./22_252_mpnn_probs.weights
# Verarbeite Datei: ./0_587_mpnn_probs.weights
# Verarbeite Datei: ./15_775_mpnn_probs.weights
# Verarbeite Datei: ./0_268_mpnn_probs.weights
# Verarbeite Datei: ./9_454_mpnn_probs.weights
# Verarbeite Datei: ./20_246_mpnn_probs.weights
# Verarbeite Datei: ./15_820_mpnn_probs.weights
# Verarbeite Datei: ./10_273_mpnn_probs.weights
# Verarbeite Datei: ./0_178_mpnn_probs.weights
# Verarbeite Datei: ./16_974_mpnn_probs.weights
# Verarbeite Datei: ./5_235_mpnn_probs.weights
# Verarbeite Datei: ./15_95_mpnn_probs.weights
# Verarbeite Datei: ./0_254_mpnn_probs.weights
# Verarbeite Datei: ./0_467_mpnn_probs.weights
# Verarbeite Datei: ./15_717_mpnn_probs.weights
# Verarbeite Datei: ./9_743_mpnn_probs.weights
# Verarbeite Datei: ./0_521_mpnn_probs.weights
# Verarbeite Datei: ./22_183_mpnn_probs.weights
# Verarbeite Datei: ./5_135_mpnn_probs.weights
# Verarbeite Datei: ./9_512_mpnn_probs.weights
# Verarbeite Datei: ./16_483_mpnn_probs.weights
# Verarbeite Datei: ./0_639_mpnn_probs.weights
# Verarbeite Datei: ./20_42_mpnn_probs.weights
# Verarbeite Datei: ./14_686_mpnn_probs.weights
# Verarbeite Datei: ./13_645_mpnn_probs.weights
# Verarbeite Datei: ./5_692_mpnn_probs.weights
# Verarbeite Datei: ./5_439_mpnn_probs.weights
# Verarbeite Datei: ./10_956_mpnn_probs.weights
# Verarbeite Datei: ./9_61_mpnn_probs.weights
# Verarbeite Datei: ./9_16_mpnn_probs.weights
# Verarbeite Datei: ./9_433_mpnn_probs.weights
# Verarbeite Datei: ./5_24_mpnn_probs.weights
# Verarbeite Datei: ./22_366_mpnn_probs.weights
# Verarbeite Datei: ./20_232_mpnn_probs.weights
# Verarbeite Datei: ./5_914_mpnn_probs.weights
# Verarbeite Datei: ./10_723_mpnn_probs.weights
# Verarbeite Datei: ./14_475_mpnn_probs.weights
# Verarbeite Datei: ./13_973_mpnn_probs.weights
# Verarbeite Datei: ./10_414_mpnn_probs.weights
# Verarbeite Datei: ./14_484_mpnn_probs.weights
# Verarbeite Datei: ./22_186_mpnn_probs.weights
# Verarbeite Datei: ./20_484_mpnn_probs.weights
# Verarbeite Datei: ./15_103_mpnn_probs.weights
# Verarbeite Datei: ./15_866_mpnn_probs.weights
# Verarbeite Datei: ./9_771_mpnn_probs.weights
# Verarbeite Datei: ./5_939_mpnn_probs.weights
# Verarbeite Datei: ./5_960_mpnn_probs.weights
# Verarbeite Datei: ./13_804_mpnn_probs.weights
# Verarbeite Datei: ./5_707_mpnn_probs.weights
# Verarbeite Datei: ./16_935_mpnn_probs.weights
# Verarbeite Datei: ./22_558_mpnn_probs.weights
# Verarbeite Datei: ./22_270_mpnn_probs.weights
# Verarbeite Datei: ./16_187_mpnn_probs.weights
# Verarbeite Datei: ./20_439_mpnn_probs.weights
# Verarbeite Datei: ./15_609_mpnn_probs.weights
# Verarbeite Datei: ./20_851_mpnn_probs.weights
# Verarbeite Datei: ./20_940_mpnn_probs.weights
# Verarbeite Datei: ./15_777_mpnn_probs.weights
# Verarbeite Datei: ./0_112_mpnn_probs.weights
# Verarbeite Datei: ./13_512_mpnn_probs.weights
# Verarbeite Datei: ./9_406_mpnn_probs.weights
# Verarbeite Datei: ./15_645_mpnn_probs.weights
# Verarbeite Datei: ./15_641_mpnn_probs.weights
# Verarbeite Datei: ./9_134_mpnn_probs.weights
# Verarbeite Datei: ./16_785_mpnn_probs.weights
# Verarbeite Datei: ./22_890_mpnn_probs.weights
# Verarbeite Datei: ./14_93_mpnn_probs.weights
# Verarbeite Datei: ./15_55_mpnn_probs.weights
# Verarbeite Datei: ./14_806_mpnn_probs.weights
# Verarbeite Datei: ./15_741_mpnn_probs.weights
# Verarbeite Datei: ./22_903_mpnn_probs.weights
# Verarbeite Datei: ./10_150_mpnn_probs.weights
# Verarbeite Datei: ./22_875_mpnn_probs.weights
# Verarbeite Datei: ./20_31_mpnn_probs.weights
# Verarbeite Datei: ./20_900_mpnn_probs.weights
# Verarbeite Datei: ./5_814_mpnn_probs.weights
# Verarbeite Datei: ./5_978_mpnn_probs.weights
# Verarbeite Datei: ./10_419_mpnn_probs.weights
# Verarbeite Datei: ./16_89_mpnn_probs.weights
# Verarbeite Datei: ./13_836_mpnn_probs.weights
# Verarbeite Datei: ./13_859_mpnn_probs.weights
# Verarbeite Datei: ./10_114_mpnn_probs.weights
# Verarbeite Datei: ./16_689_mpnn_probs.weights
# Verarbeite Datei: ./10_906_mpnn_probs.weights
# Verarbeite Datei: ./13_468_mpnn_probs.weights
# Verarbeite Datei: ./14_333_mpnn_probs.weights
# Verarbeite Datei: ./9_123_mpnn_probs.weights
# Verarbeite Datei: ./10_384_mpnn_probs.weights
# Verarbeite Datei: ./13_401_mpnn_probs.weights
# Verarbeite Datei: ./16_391_mpnn_probs.weights
# Verarbeite Datei: ./13_290_mpnn_probs.weights
# Verarbeite Datei: ./13_92_mpnn_probs.weights
# Verarbeite Datei: ./0_248_mpnn_probs.weights
# Verarbeite Datei: ./16_485_mpnn_probs.weights
# Verarbeite Datei: ./22_57_mpnn_probs.weights
# Verarbeite Datei: ./20_350_mpnn_probs.weights
# Verarbeite Datei: ./22_374_mpnn_probs.weights
# Verarbeite Datei: ./14_537_mpnn_probs.weights
# Verarbeite Datei: ./13_495_mpnn_probs.weights
# Verarbeite Datei: ./20_217_mpnn_probs.weights
# Verarbeite Datei: ./10_891_mpnn_probs.weights
# Verarbeite Datei: ./0_186_mpnn_probs.weights
# Verarbeite Datei: ./0_862_mpnn_probs.weights
# Verarbeite Datei: ./5_830_mpnn_probs.weights
# Verarbeite Datei: ./15_354_mpnn_probs.weights
# Verarbeite Datei: ./20_172_mpnn_probs.weights
# Verarbeite Datei: ./22_823_mpnn_probs.weights
# Verarbeite Datei: ./13_184_mpnn_probs.weights
# Verarbeite Datei: ./10_849_mpnn_probs.weights
# Verarbeite Datei: ./16_492_mpnn_probs.weights
# Verarbeite Datei: ./13_470_mpnn_probs.weights
# Verarbeite Datei: ./9_505_mpnn_probs.weights
# Verarbeite Datei: ./15_187_mpnn_probs.weights
# Verarbeite Datei: ./13_513_mpnn_probs.weights
# Verarbeite Datei: ./10_613_mpnn_probs.weights
# Verarbeite Datei: ./20_138_mpnn_probs.weights
# Verarbeite Datei: ./15_903_mpnn_probs.weights
# Verarbeite Datei: ./16_690_mpnn_probs.weights
# Verarbeite Datei: ./13_537_mpnn_probs.weights
# Verarbeite Datei: ./15_127_mpnn_probs.weights
# Verarbeite Datei: ./22_492_mpnn_probs.weights
# Verarbeite Datei: ./14_762_mpnn_probs.weights
# Verarbeite Datei: ./0_320_mpnn_probs.weights
# Verarbeite Datei: ./13_308_mpnn_probs.weights
# Verarbeite Datei: ./10_550_mpnn_probs.weights
# Verarbeite Datei: ./13_402_mpnn_probs.weights
# Verarbeite Datei: ./5_738_mpnn_probs.weights
# Verarbeite Datei: ./15_212_mpnn_probs.weights
# Verarbeite Datei: ./22_737_mpnn_probs.weights
# Verarbeite Datei: ./5_560_mpnn_probs.weights
# Verarbeite Datei: ./16_840_mpnn_probs.weights
# Verarbeite Datei: ./22_762_mpnn_probs.weights
# Verarbeite Datei: ./14_593_mpnn_probs.weights
# Verarbeite Datei: ./0_16_mpnn_probs.weights
# Verarbeite Datei: ./13_86_mpnn_probs.weights
# Verarbeite Datei: ./22_304_mpnn_probs.weights
# Verarbeite Datei: ./9_628_mpnn_probs.weights
# Verarbeite Datei: ./14_920_mpnn_probs.weights
# Verarbeite Datei: ./22_863_mpnn_probs.weights
# Verarbeite Datei: ./0_77_mpnn_probs.weights
# Verarbeite Datei: ./5_750_mpnn_probs.weights
# Verarbeite Datei: ./16_791_mpnn_probs.weights
# Verarbeite Datei: ./10_650_mpnn_probs.weights
# Verarbeite Datei: ./22_979_mpnn_probs.weights
# Verarbeite Datei: ./14_252_mpnn_probs.weights
# Verarbeite Datei: ./9_455_mpnn_probs.weights
# Verarbeite Datei: ./14_520_mpnn_probs.weights
# Verarbeite Datei: ./0_188_mpnn_probs.weights
# Verarbeite Datei: ./5_1000_mpnn_probs.weights
# Verarbeite Datei: ./15_533_mpnn_probs.weights
# Verarbeite Datei: ./9_137_mpnn_probs.weights
# Verarbeite Datei: ./20_964_mpnn_probs.weights
# Verarbeite Datei: ./0_144_mpnn_probs.weights
# Verarbeite Datei: ./10_354_mpnn_probs.weights
# Verarbeite Datei: ./16_677_mpnn_probs.weights
# Verarbeite Datei: ./14_508_mpnn_probs.weights
# Verarbeite Datei: ./10_861_mpnn_probs.weights
# Verarbeite Datei: ./13_42_mpnn_probs.weights
# Verarbeite Datei: ./5_585_mpnn_probs.weights
# Verarbeite Datei: ./10_300_mpnn_probs.weights
# Verarbeite Datei: ./0_4_mpnn_probs.weights
# Verarbeite Datei: ./22_818_mpnn_probs.weights
# Verarbeite Datei: ./14_555_mpnn_probs.weights
# Verarbeite Datei: ./16_656_mpnn_probs.weights
# Verarbeite Datei: ./5_249_mpnn_probs.weights
# Verarbeite Datei: ./0_435_mpnn_probs.weights
# Verarbeite Datei: ./13_442_mpnn_probs.weights
# Verarbeite Datei: ./0_601_mpnn_probs.weights
# Verarbeite Datei: ./20_918_mpnn_probs.weights
# Verarbeite Datei: ./22_229_mpnn_probs.weights
# Verarbeite Datei: ./10_639_mpnn_probs.weights
# Verarbeite Datei: ./0_720_mpnn_probs.weights
# Verarbeite Datei: ./16_450_mpnn_probs.weights
# Verarbeite Datei: ./9_949_mpnn_probs.weights
# Verarbeite Datei: ./5_697_mpnn_probs.weights
# Verarbeite Datei: ./13_889_mpnn_probs.weights
# Verarbeite Datei: ./15_53_mpnn_probs.weights
# Verarbeite Datei: ./15_24_mpnn_probs.weights
# Verarbeite Datei: ./14_825_mpnn_probs.weights
# Verarbeite Datei: ./13_579_mpnn_probs.weights
# Verarbeite Datei: ./22_23_mpnn_probs.weights
# Verarbeite Datei: ./20_133_mpnn_probs.weights
# Verarbeite Datei: ./14_980_mpnn_probs.weights
# Verarbeite Datei: ./14_448_mpnn_probs.weights
# Verarbeite Datei: ./16_240_mpnn_probs.weights
# Verarbeite Datei: ./0_560_mpnn_probs.weights
# Verarbeite Datei: ./13_252_mpnn_probs.weights
# Verarbeite Datei: ./13_896_mpnn_probs.weights
# Verarbeite Datei: ./9_580_mpnn_probs.weights
# Verarbeite Datei: ./9_212_mpnn_probs.weights
# Verarbeite Datei: ./16_638_mpnn_probs.weights
# Verarbeite Datei: ./14_900_mpnn_probs.weights
# Verarbeite Datei: ./22_19_mpnn_probs.weights
# Verarbeite Datei: ./13_937_mpnn_probs.weights
# Verarbeite Datei: ./5_623_mpnn_probs.weights
# Verarbeite Datei: ./15_770_mpnn_probs.weights
# Verarbeite Datei: ./10_877_mpnn_probs.weights
# Verarbeite Datei: ./13_30_mpnn_probs.weights
# Verarbeite Datei: ./0_540_mpnn_probs.weights
# Verarbeite Datei: ./22_897_mpnn_probs.weights
# Verarbeite Datei: ./0_43_mpnn_probs.weights
# Verarbeite Datei: ./9_191_mpnn_probs.weights
# Verarbeite Datei: ./9_746_mpnn_probs.weights
# Verarbeite Datei: ./14_644_mpnn_probs.weights
# Verarbeite Datei: ./15_70_mpnn_probs.weights
# Verarbeite Datei: ./13_145_mpnn_probs.weights
# Verarbeite Datei: ./10_362_mpnn_probs.weights
# Verarbeite Datei: ./0_1000_mpnn_probs.weights
# Verarbeite Datei: ./9_357_mpnn_probs.weights
# Verarbeite Datei: ./15_183_mpnn_probs.weights
# Verarbeite Datei: ./9_667_mpnn_probs.weights
# Verarbeite Datei: ./0_685_mpnn_probs.weights
# Verarbeite Datei: ./16_965_mpnn_probs.weights
# Verarbeite Datei: ./10_617_mpnn_probs.weights
# Verarbeite Datei: ./15_211_mpnn_probs.weights
# Verarbeite Datei: ./13_121_mpnn_probs.weights
# Verarbeite Datei: ./10_260_mpnn_probs.weights
# Verarbeite Datei: ./16_276_mpnn_probs.weights
# Verarbeite Datei: ./9_754_mpnn_probs.weights
# Verarbeite Datei: ./16_959_mpnn_probs.weights
# Verarbeite Datei: ./14_452_mpnn_probs.weights
# Verarbeite Datei: ./10_156_mpnn_probs.weights
# Verarbeite Datei: ./20_778_mpnn_probs.weights
# Verarbeite Datei: ./22_776_mpnn_probs.weights
# Verarbeite Datei: ./20_745_mpnn_probs.weights
# Verarbeite Datei: ./16_500_mpnn_probs.weights
# Verarbeite Datei: ./16_614_mpnn_probs.weights
# Verarbeite Datei: ./0_702_mpnn_probs.weights
# Verarbeite Datei: ./5_868_mpnn_probs.weights
# Verarbeite Datei: ./20_595_mpnn_probs.weights
# Verarbeite Datei: ./5_663_mpnn_probs.weights
# Verarbeite Datei: ./5_494_mpnn_probs.weights
# Verarbeite Datei: ./22_701_mpnn_probs.weights
# Verarbeite Datei: ./20_677_mpnn_probs.weights
# Verarbeite Datei: ./20_879_mpnn_probs.weights
# Verarbeite Datei: ./14_481_mpnn_probs.weights
# Verarbeite Datei: ./5_808_mpnn_probs.weights
# Verarbeite Datei: ./15_90_mpnn_probs.weights
# Verarbeite Datei: ./14_389_mpnn_probs.weights
# Verarbeite Datei: ./15_492_mpnn_probs.weights
# Verarbeite Datei: ./5_785_mpnn_probs.weights
# Verarbeite Datei: ./5_300_mpnn_probs.weights
# Verarbeite Datei: ./22_956_mpnn_probs.weights
# Verarbeite Datei: ./20_377_mpnn_probs.weights
# Verarbeite Datei: ./5_509_mpnn_probs.weights
# Verarbeite Datei: ./13_429_mpnn_probs.weights
# Verarbeite Datei: ./16_731_mpnn_probs.weights
# Verarbeite Datei: ./5_237_mpnn_probs.weights
# Verarbeite Datei: ./5_723_mpnn_probs.weights
# Verarbeite Datei: ./0_68_mpnn_probs.weights
# Verarbeite Datei: ./0_60_mpnn_probs.weights
# Verarbeite Datei: ./15_11_mpnn_probs.weights
# Verarbeite Datei: ./15_635_mpnn_probs.weights
# Verarbeite Datei: ./10_967_mpnn_probs.weights
# Verarbeite Datei: ./15_671_mpnn_probs.weights
# Verarbeite Datei: ./9_446_mpnn_probs.weights
# Verarbeite Datei: ./0_611_mpnn_probs.weights
# Verarbeite Datei: ./10_288_mpnn_probs.weights
# Verarbeite Datei: ./0_266_mpnn_probs.weights
# Verarbeite Datei: ./0_446_mpnn_probs.weights
# Verarbeite Datei: ./13_394_mpnn_probs.weights
# Verarbeite Datei: ./22_894_mpnn_probs.weights
# Verarbeite Datei: ./15_503_mpnn_probs.weights
# Verarbeite Datei: ./9_182_mpnn_probs.weights
# Verarbeite Datei: ./15_191_mpnn_probs.weights
# Verarbeite Datei: ./14_690_mpnn_probs.weights
# Verarbeite Datei: ./5_744_mpnn_probs.weights
# Verarbeite Datei: ./9_145_mpnn_probs.weights
# Verarbeite Datei: ./10_439_mpnn_probs.weights
# Verarbeite Datei: ./9_346_mpnn_probs.weights
# Verarbeite Datei: ./13_934_mpnn_probs.weights
# Verarbeite Datei: ./0_79_mpnn_probs.weights
# Verarbeite Datei: ./13_109_mpnn_probs.weights
# Verarbeite Datei: ./13_740_mpnn_probs.weights
# Verarbeite Datei: ./0_274_mpnn_probs.weights
# Verarbeite Datei: ./14_119_mpnn_probs.weights
# Verarbeite Datei: ./9_965_mpnn_probs.weights
# Verarbeite Datei: ./22_316_mpnn_probs.weights
# Verarbeite Datei: ./0_233_mpnn_probs.weights
# Verarbeite Datei: ./13_389_mpnn_probs.weights
# Verarbeite Datei: ./14_436_mpnn_probs.weights
# Verarbeite Datei: ./5_601_mpnn_probs.weights
# Verarbeite Datei: ./0_498_mpnn_probs.weights
# Verarbeite Datei: ./13_55_mpnn_probs.weights
# Verarbeite Datei: ./10_564_mpnn_probs.weights
# Verarbeite Datei: ./10_801_mpnn_probs.weights
# Verarbeite Datei: ./0_536_mpnn_probs.weights
# Verarbeite Datei: ./22_576_mpnn_probs.weights
# Verarbeite Datei: ./22_892_mpnn_probs.weights
# Verarbeite Datei: ./0_930_mpnn_probs.weights
# Verarbeite Datei: ./10_717_mpnn_probs.weights
# Verarbeite Datei: ./15_246_mpnn_probs.weights
# Verarbeite Datei: ./14_270_mpnn_probs.weights
# Verarbeite Datei: ./10_212_mpnn_probs.weights
# Verarbeite Datei: ./10_385_mpnn_probs.weights
# Verarbeite Datei: ./14_716_mpnn_probs.weights
# Verarbeite Datei: ./10_766_mpnn_probs.weights
# Verarbeite Datei: ./0_362_mpnn_probs.weights
# Verarbeite Datei: ./20_814_mpnn_probs.weights
# Verarbeite Datei: ./0_34_mpnn_probs.weights
# Verarbeite Datei: ./9_169_mpnn_probs.weights
# Verarbeite Datei: ./20_810_mpnn_probs.weights
# Verarbeite Datei: ./10_52_mpnn_probs.weights
# Verarbeite Datei: ./13_516_mpnn_probs.weights
# Verarbeite Datei: ./22_536_mpnn_probs.weights
# Verarbeite Datei: ./9_528_mpnn_probs.weights
# Verarbeite Datei: ./0_694_mpnn_probs.weights
# Verarbeite Datei: ./14_305_mpnn_probs.weights
# Verarbeite Datei: ./14_831_mpnn_probs.weights
# Verarbeite Datei: ./16_106_mpnn_probs.weights
# Verarbeite Datei: ./0_710_mpnn_probs.weights
# Verarbeite Datei: ./5_871_mpnn_probs.weights
# Verarbeite Datei: ./14_23_mpnn_probs.weights
# Verarbeite Datei: ./5_378_mpnn_probs.weights
# Verarbeite Datei: ./20_792_mpnn_probs.weights
# Verarbeite Datei: ./22_631_mpnn_probs.weights
# Verarbeite Datei: ./10_463_mpnn_probs.weights
# Verarbeite Datei: ./15_254_mpnn_probs.weights
# Verarbeite Datei: ./5_879_mpnn_probs.weights
# Verarbeite Datei: ./14_170_mpnn_probs.weights
# Verarbeite Datei: ./15_126_mpnn_probs.weights
# Verarbeite Datei: ./13_718_mpnn_probs.weights
# Verarbeite Datei: ./10_573_mpnn_probs.weights
# Verarbeite Datei: ./5_1_mpnn_probs.weights
# Verarbeite Datei: ./10_364_mpnn_probs.weights
# Verarbeite Datei: ./15_258_mpnn_probs.weights
# Verarbeite Datei: ./9_790_mpnn_probs.weights
# Verarbeite Datei: ./13_212_mpnn_probs.weights
# Verarbeite Datei: ./16_917_mpnn_probs.weights
# Verarbeite Datei: ./0_480_mpnn_probs.weights
# Verarbeite Datei: ./15_736_mpnn_probs.weights
# Verarbeite Datei: ./10_693_mpnn_probs.weights
# Verarbeite Datei: ./0_956_mpnn_probs.weights
# Verarbeite Datei: ./10_668_mpnn_probs.weights
# Verarbeite Datei: ./20_986_mpnn_probs.weights
# Verarbeite Datei: ./10_823_mpnn_probs.weights
# Verarbeite Datei: ./9_887_mpnn_probs.weights
# Verarbeite Datei: ./22_834_mpnn_probs.weights
# Verarbeite Datei: ./16_853_mpnn_probs.weights
# Verarbeite Datei: ./20_567_mpnn_probs.weights
# Verarbeite Datei: ./22_165_mpnn_probs.weights
# Verarbeite Datei: ./5_313_mpnn_probs.weights
# Verarbeite Datei: ./15_774_mpnn_probs.weights
# Verarbeite Datei: ./16_556_mpnn_probs.weights
# Verarbeite Datei: ./20_919_mpnn_probs.weights
# Verarbeite Datei: ./14_871_mpnn_probs.weights
# Verarbeite Datei: ./10_228_mpnn_probs.weights
# Verarbeite Datei: ./20_769_mpnn_probs.weights
# Verarbeite Datei: ./16_344_mpnn_probs.weights
# Verarbeite Datei: ./9_804_mpnn_probs.weights
# Verarbeite Datei: ./13_207_mpnn_probs.weights
# Verarbeite Datei: ./10_168_mpnn_probs.weights
# Verarbeite Datei: ./13_672_mpnn_probs.weights
# Verarbeite Datei: ./15_277_mpnn_probs.weights
# Verarbeite Datei: ./22_614_mpnn_probs.weights
# Verarbeite Datei: ./5_555_mpnn_probs.weights
# Verarbeite Datei: ./15_832_mpnn_probs.weights
# Verarbeite Datei: ./16_323_mpnn_probs.weights
# Verarbeite Datei: ./13_500_mpnn_probs.weights
# Verarbeite Datei: ./20_827_mpnn_probs.weights
# Verarbeite Datei: ./13_291_mpnn_probs.weights
# Verarbeite Datei: ./10_15_mpnn_probs.weights
# Verarbeite Datei: ./9_549_mpnn_probs.weights
# Verarbeite Datei: ./22_611_mpnn_probs.weights
# Verarbeite Datei: ./15_448_mpnn_probs.weights
# Verarbeite Datei: ./16_342_mpnn_probs.weights
# Verarbeite Datei: ./22_680_mpnn_probs.weights
# Verarbeite Datei: ./15_34_mpnn_probs.weights
# Verarbeite Datei: ./0_838_mpnn_probs.weights
# Verarbeite Datei: ./16_77_mpnn_probs.weights
# Verarbeite Datei: ./20_53_mpnn_probs.weights
# Verarbeite Datei: ./0_353_mpnn_probs.weights
# Verarbeite Datei: ./16_321_mpnn_probs.weights
# Verarbeite Datei: ./9_467_mpnn_probs.weights
# Verarbeite Datei: ./22_590_mpnn_probs.weights
# Verarbeite Datei: ./15_747_mpnn_probs.weights
# Verarbeite Datei: ./9_997_mpnn_probs.weights
# Verarbeite Datei: ./9_785_mpnn_probs.weights
# Verarbeite Datei: ./10_450_mpnn_probs.weights
# Verarbeite Datei: ./9_806_mpnn_probs.weights
# Verarbeite Datei: ./0_153_mpnn_probs.weights
# Verarbeite Datei: ./15_559_mpnn_probs.weights
# Verarbeite Datei: ./20_817_mpnn_probs.weights
# Verarbeite Datei: ./0_334_mpnn_probs.weights
# Verarbeite Datei: ./10_691_mpnn_probs.weights
# Verarbeite Datei: ./10_620_mpnn_probs.weights
# Verarbeite Datei: ./10_770_mpnn_probs.weights
# Verarbeite Datei: ./15_76_mpnn_probs.weights
# Verarbeite Datei: ./15_370_mpnn_probs.weights
# Verarbeite Datei: ./13_805_mpnn_probs.weights
# Verarbeite Datei: ./10_887_mpnn_probs.weights
# Verarbeite Datei: ./9_337_mpnn_probs.weights
# Verarbeite Datei: ./13_677_mpnn_probs.weights
# Verarbeite Datei: ./20_420_mpnn_probs.weights
# Verarbeite Datei: ./0_19_mpnn_probs.weights
# Verarbeite Datei: ./16_807_mpnn_probs.weights
# Verarbeite Datei: ./14_505_mpnn_probs.weights
# Verarbeite Datei: ./9_721_mpnn_probs.weights
# Verarbeite Datei: ./10_376_mpnn_probs.weights
# Verarbeite Datei: ./20_725_mpnn_probs.weights
# Verarbeite Datei: ./13_800_mpnn_probs.weights
# Verarbeite Datei: ./9_47_mpnn_probs.weights
# Verarbeite Datei: ./20_508_mpnn_probs.weights
# Verarbeite Datei: ./20_1_mpnn_probs.weights
# Verarbeite Datei: ./13_593_mpnn_probs.weights
# Verarbeite Datei: ./20_495_mpnn_probs.weights
# Verarbeite Datei: ./16_536_mpnn_probs.weights
# Verarbeite Datei: ./9_386_mpnn_probs.weights
# Verarbeite Datei: ./15_75_mpnn_probs.weights
# Verarbeite Datei: ./15_550_mpnn_probs.weights
# Verarbeite Datei: ./13_904_mpnn_probs.weights
# Verarbeite Datei: ./20_943_mpnn_probs.weights
# Verarbeite Datei: ./16_435_mpnn_probs.weights
# Verarbeite Datei: ./14_399_mpnn_probs.weights
# Verarbeite Datei: ./13_536_mpnn_probs.weights
# Verarbeite Datei: ./16_569_mpnn_probs.weights
# Verarbeite Datei: ./15_436_mpnn_probs.weights
# Verarbeite Datei: ./13_716_mpnn_probs.weights
# Verarbeite Datei: ./20_69_mpnn_probs.weights
# Verarbeite Datei: ./10_223_mpnn_probs.weights
# Verarbeite Datei: ./0_384_mpnn_probs.weights
# Verarbeite Datei: ./0_97_mpnn_probs.weights
# Verarbeite Datei: ./9_526_mpnn_probs.weights
# Verarbeite Datei: ./16_345_mpnn_probs.weights
# Verarbeite Datei: ./15_82_mpnn_probs.weights
# Verarbeite Datei: ./16_799_mpnn_probs.weights
# Verarbeite Datei: ./14_66_mpnn_probs.weights
# Verarbeite Datei: ./14_622_mpnn_probs.weights
# Verarbeite Datei: ./9_440_mpnn_probs.weights
# Verarbeite Datei: ./0_867_mpnn_probs.weights
# Verarbeite Datei: ./14_346_mpnn_probs.weights
# Verarbeite Datei: ./13_894_mpnn_probs.weights
# Verarbeite Datei: ./14_382_mpnn_probs.weights
# Verarbeite Datei: ./10_784_mpnn_probs.weights
# Verarbeite Datei: ./10_306_mpnn_probs.weights
# Verarbeite Datei: ./13_187_mpnn_probs.weights
# Verarbeite Datei: ./20_216_mpnn_probs.weights
# Verarbeite Datei: ./0_479_mpnn_probs.weights
# Verarbeite Datei: ./10_351_mpnn_probs.weights
# Verarbeite Datei: ./20_954_mpnn_probs.weights
# Verarbeite Datei: ./0_592_mpnn_probs.weights
# Verarbeite Datei: ./15_904_mpnn_probs.weights
# Verarbeite Datei: ./15_973_mpnn_probs.weights
# Verarbeite Datei: ./0_907_mpnn_probs.weights
# Verarbeite Datei: ./20_543_mpnn_probs.weights
# Verarbeite Datei: ./5_200_mpnn_probs.weights
# Verarbeite Datei: ./5_358_mpnn_probs.weights
# Verarbeite Datei: ./14_295_mpnn_probs.weights
# Verarbeite Datei: ./14_752_mpnn_probs.weights
# Verarbeite Datei: ./16_368_mpnn_probs.weights
# Verarbeite Datei: ./14_370_mpnn_probs.weights
# Verarbeite Datei: ./15_83_mpnn_probs.weights
# Verarbeite Datei: ./9_394_mpnn_probs.weights
# Verarbeite Datei: ./15_577_mpnn_probs.weights
# Verarbeite Datei: ./22_292_mpnn_probs.weights
# Verarbeite Datei: ./10_894_mpnn_probs.weights
# Verarbeite Datei: ./13_7_mpnn_probs.weights
# Verarbeite Datei: ./20_893_mpnn_probs.weights
# Verarbeite Datei: ./14_447_mpnn_probs.weights
# Verarbeite Datei: ./22_588_mpnn_probs.weights
# Verarbeite Datei: ./15_193_mpnn_probs.weights
# Verarbeite Datei: ./14_669_mpnn_probs.weights
# Verarbeite Datei: ./5_975_mpnn_probs.weights
# Verarbeite Datei: ./0_448_mpnn_probs.weights
# Verarbeite Datei: ./20_263_mpnn_probs.weights
# Verarbeite Datei: ./10_73_mpnn_probs.weights
# Verarbeite Datei: ./16_298_mpnn_probs.weights
# Verarbeite Datei: ./0_575_mpnn_probs.weights
# Verarbeite Datei: ./13_210_mpnn_probs.weights
# Verarbeite Datei: ./15_266_mpnn_probs.weights
# Verarbeite Datei: ./16_981_mpnn_probs.weights
# Verarbeite Datei: ./22_494_mpnn_probs.weights
# Verarbeite Datei: ./13_96_mpnn_probs.weights
# Verarbeite Datei: ./22_566_mpnn_probs.weights
# Verarbeite Datei: ./14_938_mpnn_probs.weights
# Verarbeite Datei: ./14_316_mpnn_probs.weights
# Verarbeite Datei: ./10_279_mpnn_probs.weights
# Verarbeite Datei: ./14_923_mpnn_probs.weights
# Verarbeite Datei: ./5_39_mpnn_probs.weights
# Verarbeite Datei: ./10_479_mpnn_probs.weights
# Verarbeite Datei: ./15_48_mpnn_probs.weights
# Verarbeite Datei: ./9_234_mpnn_probs.weights
# Verarbeite Datei: ./22_113_mpnn_probs.weights
# Verarbeite Datei: ./13_938_mpnn_probs.weights
# Verarbeite Datei: ./0_187_mpnn_probs.weights
# Verarbeite Datei: ./13_440_mpnn_probs.weights
# Verarbeite Datei: ./9_261_mpnn_probs.weights
# Verarbeite Datei: ./22_900_mpnn_probs.weights
# Verarbeite Datei: ./10_373_mpnn_probs.weights
# Verarbeite Datei: ./15_65_mpnn_probs.weights
# Verarbeite Datei: ./5_96_mpnn_probs.weights
# Verarbeite Datei: ./16_65_mpnn_probs.weights
# Verarbeite Datei: ./15_275_mpnn_probs.weights
# Verarbeite Datei: ./15_415_mpnn_probs.weights
# Verarbeite Datei: ./16_352_mpnn_probs.weights
# Verarbeite Datei: ./15_807_mpnn_probs.weights
# Verarbeite Datei: ./20_925_mpnn_probs.weights
# Verarbeite Datei: ./9_409_mpnn_probs.weights
# Verarbeite Datei: ./13_271_mpnn_probs.weights
# Verarbeite Datei: ./0_402_mpnn_probs.weights
# Verarbeite Datei: ./13_320_mpnn_probs.weights
# Verarbeite Datei: ./20_488_mpnn_probs.weights
# Verarbeite Datei: ./13_959_mpnn_probs.weights
# Verarbeite Datei: ./9_556_mpnn_probs.weights
# Verarbeite Datei: ./15_964_mpnn_probs.weights
# Verarbeite Datei: ./14_383_mpnn_probs.weights
# Verarbeite Datei: ./15_298_mpnn_probs.weights
# Verarbeite Datei: ./22_667_mpnn_probs.weights
# Verarbeite Datei: ./15_480_mpnn_probs.weights
# Verarbeite Datei: ./10_732_mpnn_probs.weights
# Verarbeite Datei: ./0_679_mpnn_probs.weights
# Verarbeite Datei: ./22_921_mpnn_probs.weights
# Verarbeite Datei: ./16_962_mpnn_probs.weights
# Verarbeite Datei: ./22_50_mpnn_probs.weights
# Verarbeite Datei: ./9_175_mpnn_probs.weights
# Verarbeite Datei: ./22_140_mpnn_probs.weights
# Verarbeite Datei: ./5_80_mpnn_probs.weights
# Verarbeite Datei: ./16_381_mpnn_probs.weights
# Verarbeite Datei: ./9_538_mpnn_probs.weights
# Verarbeite Datei: ./9_984_mpnn_probs.weights
# Verarbeite Datei: ./5_677_mpnn_probs.weights
# Verarbeite Datei: ./16_672_mpnn_probs.weights
# Verarbeite Datei: ./5_463_mpnn_probs.weights
# Verarbeite Datei: ./5_214_mpnn_probs.weights
# Verarbeite Datei: ./9_963_mpnn_probs.weights
# Verarbeite Datei: ./13_260_mpnn_probs.weights
# Verarbeite Datei: ./13_559_mpnn_probs.weights
# Verarbeite Datei: ./9_140_mpnn_probs.weights
# Verarbeite Datei: ./9_638_mpnn_probs.weights
# Verarbeite Datei: ./22_836_mpnn_probs.weights
# Verarbeite Datei: ./20_681_mpnn_probs.weights
# Verarbeite Datei: ./9_999_mpnn_probs.weights
# Verarbeite Datei: ./13_989_mpnn_probs.weights
# Verarbeite Datei: ./0_509_mpnn_probs.weights
# Verarbeite Datei: ./5_733_mpnn_probs.weights
# Verarbeite Datei: ./15_287_mpnn_probs.weights
# Verarbeite Datei: ./22_944_mpnn_probs.weights
# Verarbeite Datei: ./16_263_mpnn_probs.weights
# Verarbeite Datei: ./22_77_mpnn_probs.weights
# Verarbeite Datei: ./10_315_mpnn_probs.weights
# Verarbeite Datei: ./0_243_mpnn_probs.weights
# Verarbeite Datei: ./14_993_mpnn_probs.weights
# Verarbeite Datei: ./15_362_mpnn_probs.weights
# Verarbeite Datei: ./5_671_mpnn_probs.weights
# Verarbeite Datei: ./13_434_mpnn_probs.weights
# Verarbeite Datei: ./15_437_mpnn_probs.weights
# Verarbeite Datei: ./20_999_mpnn_probs.weights
# Verarbeite Datei: ./5_458_mpnn_probs.weights
# Verarbeite Datei: ./0_231_mpnn_probs.weights
# Verarbeite Datei: ./15_696_mpnn_probs.weights
# Verarbeite Datei: ./0_102_mpnn_probs.weights
# Verarbeite Datei: ./14_337_mpnn_probs.weights
# Verarbeite Datei: ./20_89_mpnn_probs.weights
# Verarbeite Datei: ./10_175_mpnn_probs.weights
# Verarbeite Datei: ./5_324_mpnn_probs.weights
# Verarbeite Datei: ./22_742_mpnn_probs.weights
# Verarbeite Datei: ./0_617_mpnn_probs.weights
# Verarbeite Datei: ./15_224_mpnn_probs.weights
# Verarbeite Datei: ./22_606_mpnn_probs.weights
# Verarbeite Datei: ./14_777_mpnn_probs.weights
# Verarbeite Datei: ./14_240_mpnn_probs.weights
# Verarbeite Datei: ./20_840_mpnn_probs.weights
# Verarbeite Datei: ./10_166_mpnn_probs.weights
# Verarbeite Datei: ./10_412_mpnn_probs.weights
# Verarbeite Datei: ./10_498_mpnn_probs.weights
# Verarbeite Datei: ./13_711_mpnn_probs.weights
# Verarbeite Datei: ./14_246_mpnn_probs.weights
# Verarbeite Datei: ./9_967_mpnn_probs.weights
# Verarbeite Datei: ./14_736_mpnn_probs.weights
# Verarbeite Datei: ./0_5_mpnn_probs.weights
# Verarbeite Datei: ./15_795_mpnn_probs.weights
# Verarbeite Datei: ./15_351_mpnn_probs.weights
# Verarbeite Datei: ./5_584_mpnn_probs.weights
# Verarbeite Datei: ./0_657_mpnn_probs.weights
# Verarbeite Datei: ./13_371_mpnn_probs.weights
# Verarbeite Datei: ./0_305_mpnn_probs.weights
# Verarbeite Datei: ./16_714_mpnn_probs.weights
# Verarbeite Datei: ./13_49_mpnn_probs.weights
# Verarbeite Datei: ./16_740_mpnn_probs.weights
# Verarbeite Datei: ./22_414_mpnn_probs.weights
# Verarbeite Datei: ./20_492_mpnn_probs.weights
# Verarbeite Datei: ./14_563_mpnn_probs.weights
# Verarbeite Datei: ./22_381_mpnn_probs.weights
# Verarbeite Datei: ./16_961_mpnn_probs.weights
# Verarbeite Datei: ./5_303_mpnn_probs.weights
# Verarbeite Datei: ./14_209_mpnn_probs.weights
# Verarbeite Datei: ./20_26_mpnn_probs.weights
# Verarbeite Datei: ./22_204_mpnn_probs.weights
# Verarbeite Datei: ./15_614_mpnn_probs.weights
# Verarbeite Datei: ./16_562_mpnn_probs.weights
# Verarbeite Datei: ./14_142_mpnn_probs.weights
# Verarbeite Datei: ./16_333_mpnn_probs.weights
# Verarbeite Datei: ./10_13_mpnn_probs.weights
# Verarbeite Datei: ./9_407_mpnn_probs.weights
# Verarbeite Datei: ./5_267_mpnn_probs.weights
# Verarbeite Datei: ./22_164_mpnn_probs.weights
# Verarbeite Datei: ./13_77_mpnn_probs.weights
# Verarbeite Datei: ./5_974_mpnn_probs.weights
# Verarbeite Datei: ./5_632_mpnn_probs.weights
# Verarbeite Datei: ./10_953_mpnn_probs.weights
# Verarbeite Datei: ./15_538_mpnn_probs.weights
# Verarbeite Datei: ./20_968_mpnn_probs.weights
# Verarbeite Datei: ./5_8_mpnn_probs.weights
# Verarbeite Datei: ./0_612_mpnn_probs.weights
# Verarbeite Datei: ./15_870_mpnn_probs.weights
# Verarbeite Datei: ./16_189_mpnn_probs.weights
# Verarbeite Datei: ./0_421_mpnn_probs.weights
# Verarbeite Datei: ./15_58_mpnn_probs.weights
# Verarbeite Datei: ./16_36_mpnn_probs.weights
# Verarbeite Datei: ./14_321_mpnn_probs.weights
# Verarbeite Datei: ./10_944_mpnn_probs.weights
# Verarbeite Datei: ./20_614_mpnn_probs.weights
# Verarbeite Datei: ./16_33_mpnn_probs.weights
# Verarbeite Datei: ./22_25_mpnn_probs.weights
# Verarbeite Datei: ./14_895_mpnn_probs.weights
# Verarbeite Datei: ./20_794_mpnn_probs.weights
# Verarbeite Datei: ./5_110_mpnn_probs.weights
# Verarbeite Datei: ./5_272_mpnn_probs.weights
# Verarbeite Datei: ./5_719_mpnn_probs.weights
# Verarbeite Datei: ./9_122_mpnn_probs.weights
# Verarbeite Datei: ./15_42_mpnn_probs.weights
# Verarbeite Datei: ./14_829_mpnn_probs.weights
# Verarbeite Datei: ./13_181_mpnn_probs.weights
# Verarbeite Datei: ./16_312_mpnn_probs.weights
# Verarbeite Datei: ./0_283_mpnn_probs.weights
# Verarbeite Datei: ./14_949_mpnn_probs.weights
# Verarbeite Datei: ./9_759_mpnn_probs.weights
# Verarbeite Datei: ./15_243_mpnn_probs.weights
# Verarbeite Datei: ./15_643_mpnn_probs.weights
# Verarbeite Datei: ./16_325_mpnn_probs.weights
# Verarbeite Datei: ./9_506_mpnn_probs.weights
# Verarbeite Datei: ./20_207_mpnn_probs.weights
# Verarbeite Datei: ./15_458_mpnn_probs.weights
# Verarbeite Datei: ./10_139_mpnn_probs.weights
# Verarbeite Datei: ./20_272_mpnn_probs.weights
# Verarbeite Datei: ./13_127_mpnn_probs.weights
# Verarbeite Datei: ./15_838_mpnn_probs.weights
# Verarbeite Datei: ./0_447_mpnn_probs.weights
# Verarbeite Datei: ./15_506_mpnn_probs.weights
# Verarbeite Datei: ./5_979_mpnn_probs.weights
# Verarbeite Datei: ./13_993_mpnn_probs.weights
# Verarbeite Datei: ./0_349_mpnn_probs.weights
# Verarbeite Datei: ./10_689_mpnn_probs.weights
# Verarbeite Datei: ./13_226_mpnn_probs.weights
# Verarbeite Datei: ./5_260_mpnn_probs.weights
# Verarbeite Datei: ./5_822_mpnn_probs.weights
# Verarbeite Datei: ./0_937_mpnn_probs.weights
# Verarbeite Datei: ./0_390_mpnn_probs.weights
# Verarbeite Datei: ./20_354_mpnn_probs.weights
# Verarbeite Datei: ./14_794_mpnn_probs.weights
# Verarbeite Datei: ./16_982_mpnn_probs.weights
# Verarbeite Datei: ./0_84_mpnn_probs.weights
# Verarbeite Datei: ./10_290_mpnn_probs.weights
# Verarbeite Datei: ./13_208_mpnn_probs.weights
# Verarbeite Datei: ./22_838_mpnn_probs.weights
# Verarbeite Datei: ./9_111_mpnn_probs.weights
# Verarbeite Datei: ./16_433_mpnn_probs.weights
# Verarbeite Datei: ./16_283_mpnn_probs.weights
# Verarbeite Datei: ./14_485_mpnn_probs.weights
# Verarbeite Datei: ./10_530_mpnn_probs.weights
# Verarbeite Datei: ./10_408_mpnn_probs.weights
# Verarbeite Datei: ./14_511_mpnn_probs.weights
# Verarbeite Datei: ./10_927_mpnn_probs.weights
# Verarbeite Datei: ./5_322_mpnn_probs.weights
# Verarbeite Datei: ./15_32_mpnn_probs.weights
# Verarbeite Datei: ./14_355_mpnn_probs.weights
# Verarbeite Datei: ./16_728_mpnn_probs.weights
# Verarbeite Datei: ./0_363_mpnn_probs.weights
# Verarbeite Datei: ./14_456_mpnn_probs.weights
# Verarbeite Datei: ./22_312_mpnn_probs.weights
# Verarbeite Datei: ./20_209_mpnn_probs.weights
# Verarbeite Datei: ./0_556_mpnn_probs.weights
# Verarbeite Datei: ./20_729_mpnn_probs.weights
# Verarbeite Datei: ./14_710_mpnn_probs.weights
# Verarbeite Datei: ./0_836_mpnn_probs.weights
# Verarbeite Datei: ./16_603_mpnn_probs.weights
# Verarbeite Datei: ./15_763_mpnn_probs.weights
# Verarbeite Datei: ./16_167_mpnn_probs.weights
# Verarbeite Datei: ./9_152_mpnn_probs.weights
# Verarbeite Datei: ./0_429_mpnn_probs.weights
# Verarbeite Datei: ./9_458_mpnn_probs.weights
# Verarbeite Datei: ./15_952_mpnn_probs.weights
# Verarbeite Datei: ./5_635_mpnn_probs.weights
# Verarbeite Datei: ./16_587_mpnn_probs.weights
# Verarbeite Datei: ./14_390_mpnn_probs.weights
# Verarbeite Datei: ./13_485_mpnn_probs.weights
# Verarbeite Datei: ./16_331_mpnn_probs.weights
# Verarbeite Datei: ./13_738_mpnn_probs.weights
# Verarbeite Datei: ./15_168_mpnn_probs.weights
# Verarbeite Datei: ./5_384_mpnn_probs.weights
# Verarbeite Datei: ./20_28_mpnn_probs.weights
# Verarbeite Datei: ./20_965_mpnn_probs.weights
# Verarbeite Datei: ./16_196_mpnn_probs.weights
# Verarbeite Datei: ./14_392_mpnn_probs.weights
# Verarbeite Datei: ./9_100_mpnn_probs.weights
# Verarbeite Datei: ./0_792_mpnn_probs.weights
# Verarbeite Datei: ./15_81_mpnn_probs.weights
# Verarbeite Datei: ./14_781_mpnn_probs.weights
# Verarbeite Datei: ./0_745_mpnn_probs.weights
# Verarbeite Datei: ./10_243_mpnn_probs.weights
# Verarbeite Datei: ./13_527_mpnn_probs.weights
# Verarbeite Datei: ./5_951_mpnn_probs.weights
# Verarbeite Datei: ./5_958_mpnn_probs.weights
# Verarbeite Datei: ./14_248_mpnn_probs.weights
# Verarbeite Datei: ./5_742_mpnn_probs.weights
# Verarbeite Datei: ./13_330_mpnn_probs.weights
# Verarbeite Datei: ./16_220_mpnn_probs.weights
# Verarbeite Datei: ./9_130_mpnn_probs.weights
# Verarbeite Datei: ./10_304_mpnn_probs.weights
# Verarbeite Datei: ./20_602_mpnn_probs.weights
# Verarbeite Datei: ./15_981_mpnn_probs.weights
# Verarbeite Datei: ./14_339_mpnn_probs.weights
# Verarbeite Datei: ./0_928_mpnn_probs.weights
# Verarbeite Datei: ./13_649_mpnn_probs.weights
# Verarbeite Datei: ./15_725_mpnn_probs.weights
# Verarbeite Datei: ./22_132_mpnn_probs.weights
# Verarbeite Datei: ./16_985_mpnn_probs.weights
# Verarbeite Datei: ./20_168_mpnn_probs.weights
# Verarbeite Datei: ./10_618_mpnn_probs.weights
# Verarbeite Datei: ./13_420_mpnn_probs.weights
# Verarbeite Datei: ./22_11_mpnn_probs.weights
# Verarbeite Datei: ./20_279_mpnn_probs.weights
# Verarbeite Datei: ./14_819_mpnn_probs.weights
# Verarbeite Datei: ./5_418_mpnn_probs.weights
# Verarbeite Datei: ./9_270_mpnn_probs.weights
# Verarbeite Datei: ./10_468_mpnn_probs.weights
# Verarbeite Datei: ./10_722_mpnn_probs.weights
# Verarbeite Datei: ./20_79_mpnn_probs.weights
# Verarbeite Datei: ./5_980_mpnn_probs.weights
# Verarbeite Datei: ./0_754_mpnn_probs.weights
# Verarbeite Datei: ./20_747_mpnn_probs.weights
# Verarbeite Datei: ./10_163_mpnn_probs.weights
# Verarbeite Datei: ./16_901_mpnn_probs.weights
# Verarbeite Datei: ./20_19_mpnn_probs.weights
# Verarbeite Datei: ./16_169_mpnn_probs.weights
# Verarbeite Datei: ./20_532_mpnn_probs.weights
# Verarbeite Datei: ./20_196_mpnn_probs.weights
# Verarbeite Datei: ./0_13_mpnn_probs.weights
# Verarbeite Datei: ./22_538_mpnn_probs.weights
# Verarbeite Datei: ./9_35_mpnn_probs.weights
# Verarbeite Datei: ./0_843_mpnn_probs.weights
# Verarbeite Datei: ./16_557_mpnn_probs.weights
# Verarbeite Datei: ./16_328_mpnn_probs.weights
# Verarbeite Datei: ./13_809_mpnn_probs.weights
# Verarbeite Datei: ./10_177_mpnn_probs.weights
# Verarbeite Datei: ./0_503_mpnn_probs.weights
# Verarbeite Datei: ./20_186_mpnn_probs.weights
# Verarbeite Datei: ./9_166_mpnn_probs.weights
# Verarbeite Datei: ./20_499_mpnn_probs.weights
# Verarbeite Datei: ./14_977_mpnn_probs.weights
# Verarbeite Datei: ./14_303_mpnn_probs.weights
# Verarbeite Datei: ./14_985_mpnn_probs.weights
# Verarbeite Datei: ./22_636_mpnn_probs.weights
# Verarbeite Datei: ./14_363_mpnn_probs.weights
# Verarbeite Datei: ./10_333_mpnn_probs.weights
# Verarbeite Datei: ./9_76_mpnn_probs.weights
# Verarbeite Datei: ./9_707_mpnn_probs.weights
# Verarbeite Datei: ./10_804_mpnn_probs.weights
# Verarbeite Datei: ./9_119_mpnn_probs.weights
# Verarbeite Datei: ./20_651_mpnn_probs.weights
# Verarbeite Datei: ./20_184_mpnn_probs.weights
# Verarbeite Datei: ./15_532_mpnn_probs.weights
# Verarbeite Datei: ./9_423_mpnn_probs.weights
# Verarbeite Datei: ./5_748_mpnn_probs.weights
# Verarbeite Datei: ./22_112_mpnn_probs.weights
# Verarbeite Datei: ./13_381_mpnn_probs.weights
# Verarbeite Datei: ./13_118_mpnn_probs.weights
# Verarbeite Datei: ./15_727_mpnn_probs.weights
# Verarbeite Datei: ./10_821_mpnn_probs.weights
# Verarbeite Datei: ./20_141_mpnn_probs.weights
# Verarbeite Datei: ./5_886_mpnn_probs.weights
# Verarbeite Datei: ./16_315_mpnn_probs.weights
# Verarbeite Datei: ./10_753_mpnn_probs.weights
# Verarbeite Datei: ./20_716_mpnn_probs.weights
# Verarbeite Datei: ./5_664_mpnn_probs.weights
# Verarbeite Datei: ./15_885_mpnn_probs.weights
# Verarbeite Datei: ./5_629_mpnn_probs.weights
# Verarbeite Datei: ./5_86_mpnn_probs.weights
# Verarbeite Datei: ./16_52_mpnn_probs.weights
# Verarbeite Datei: ./5_647_mpnn_probs.weights
# Verarbeite Datei: ./22_203_mpnn_probs.weights
# Verarbeite Datei: ./13_639_mpnn_probs.weights
# Verarbeite Datei: ./20_895_mpnn_probs.weights
# Verarbeite Datei: ./14_367_mpnn_probs.weights
# Verarbeite Datei: ./9_103_mpnn_probs.weights
# Verarbeite Datei: ./5_577_mpnn_probs.weights
# Verarbeite Datei: ./5_565_mpnn_probs.weights
# Verarbeite Datei: ./13_333_mpnn_probs.weights
# Verarbeite Datei: ./20_623_mpnn_probs.weights
# Verarbeite Datei: ./5_114_mpnn_probs.weights
# Verarbeite Datei: ./16_739_mpnn_probs.weights
# Verarbeite Datei: ./13_892_mpnn_probs.weights
# Verarbeite Datei: ./20_550_mpnn_probs.weights
# Verarbeite Datei: ./5_21_mpnn_probs.weights
# Verarbeite Datei: ./16_436_mpnn_probs.weights
# Verarbeite Datei: ./15_17_mpnn_probs.weights
# Verarbeite Datei: ./9_958_mpnn_probs.weights
# Verarbeite Datei: ./13_713_mpnn_probs.weights
# Verarbeite Datei: ./20_442_mpnn_probs.weights
# Verarbeite Datei: ./20_82_mpnn_probs.weights
# Verarbeite Datei: ./13_190_mpnn_probs.weights
# Verarbeite Datei: ./15_578_mpnn_probs.weights
# Verarbeite Datei: ./10_568_mpnn_probs.weights
# Verarbeite Datei: ./0_493_mpnn_probs.weights
# Verarbeite Datei: ./9_583_mpnn_probs.weights
# Verarbeite Datei: ./15_131_mpnn_probs.weights
# Verarbeite Datei: ./20_606_mpnn_probs.weights
# Verarbeite Datei: ./14_912_mpnn_probs.weights
# Verarbeite Datei: ./5_423_mpnn_probs.weights
# Verarbeite Datei: ./10_788_mpnn_probs.weights
# Verarbeite Datei: ./5_915_mpnn_probs.weights
# Verarbeite Datei: ./16_27_mpnn_probs.weights
# Verarbeite Datei: ./13_952_mpnn_probs.weights
# Verarbeite Datei: ./5_811_mpnn_probs.weights
# Verarbeite Datei: ./10_289_mpnn_probs.weights
# Verarbeite Datei: ./5_410_mpnn_probs.weights
# Verarbeite Datei: ./13_307_mpnn_probs.weights
# Verarbeite Datei: ./13_550_mpnn_probs.weights
# Verarbeite Datei: ./9_575_mpnn_probs.weights
# Verarbeite Datei: ./20_648_mpnn_probs.weights
# Verarbeite Datei: ./13_345_mpnn_probs.weights
# Verarbeite Datei: ./9_104_mpnn_probs.weights
# Verarbeite Datei: ./15_31_mpnn_probs.weights
# Verarbeite Datei: ./22_751_mpnn_probs.weights
# Verarbeite Datei: ./5_513_mpnn_probs.weights
# Verarbeite Datei: ./0_230_mpnn_probs.weights
# Verarbeite Datei: ./20_147_mpnn_probs.weights
# Verarbeite Datei: ./22_493_mpnn_probs.weights
# Verarbeite Datei: ./9_450_mpnn_probs.weights
# Verarbeite Datei: ./16_477_mpnn_probs.weights
# Verarbeite Datei: ./13_958_mpnn_probs.weights
# Verarbeite Datei: ./10_690_mpnn_probs.weights
# Verarbeite Datei: ./16_825_mpnn_probs.weights
# Verarbeite Datei: ./10_346_mpnn_probs.weights
# ...
# Verarbeite Datei: ./0_535_mpnn_probs.weights
# Verarbeite Datei: ./14_775_mpnn_probs.weights
# Verarbeite Datei: ./0_288_mpnn_probs.weights
# Verarbeite Datei: ./14_9_mpnn_probs.weights
# Verarbeite Datei: ./10_800_mpnn_probs.weights
# Verarbeite Datei: ./10_860_mpnn_probs.weights
# Verarbeite Datei: ./5_65_mpnn_probs.weights
# Verarbeite Datei: ./9_313_mpnn_probs.weights
# Verarbeite Datei: ./15_66_mpnn_probs.weights
# Verarbeite Datei: ./22_752_mpnn_probs.weights
# Verarbeite Datei: ./9_793_mpnn_probs.weights
# Verarbeite Datei: ./13_203_mpnn_probs.weights
# Verarbeite Datei: ./5_192_mpnn_probs.weights
# Verarbeite Datei: ./9_98_mpnn_probs.weights
# Verarbeite Datei: ./0_638_mpnn_probs.weights
# Verarbeite Datei: ./22_995_mpnn_probs.weights
# Verarbeite Datei: ./9_890_mpnn_probs.weights
# Verarbeite Datei: ./16_376_mpnn_probs.weights
# Verarbeite Datei: ./5_952_mpnn_probs.weights
# Verarbeite Datei: ./13_975_mpnn_probs.weights
# Verarbeite Datei: ./14_371_mpnn_probs.weights
# Verarbeite Datei: ./22_862_mpnn_probs.weights
# Verarbeite Datei: ./10_157_mpnn_probs.weights
# Verarbeite Datei: ./13_745_mpnn_probs.weights
# Verarbeite Datei: ./0_332_mpnn_probs.weights
# Verarbeite Datei: ./22_591_mpnn_probs.weights
# Verarbeite Datei: ./16_404_mpnn_probs.weights
# Verarbeite Datei: ./0_365_mpnn_probs.weights
# Verarbeite Datei: ./14_199_mpnn_probs.weights
# Verarbeite Datei: ./9_361_mpnn_probs.weights
# Verarbeite Datei: ./0_492_mpnn_probs.weights
# Verarbeite Datei: ./5_907_mpnn_probs.weights
# Verarbeite Datei: ./5_693_mpnn_probs.weights
# Verarbeite Datei: ./10_838_mpnn_probs.weights
# Verarbeite Datei: ./0_214_mpnn_probs.weights
# Verarbeite Datei: ./5_502_mpnn_probs.weights
# Verarbeite Datei: ./20_696_mpnn_probs.weights
# Verarbeite Datei: ./9_41_mpnn_probs.weights
# Verarbeite Datei: ./14_850_mpnn_probs.weights
# Verarbeite Datei: ./5_679_mpnn_probs.weights
# Verarbeite Datei: ./5_311_mpnn_probs.weights
# Verarbeite Datei: ./16_787_mpnn_probs.weights
# Verarbeite Datei: ./10_553_mpnn_probs.weights
# Verarbeite Datei: ./13_380_mpnn_probs.weights
# Verarbeite Datei: ./13_341_mpnn_probs.weights
# Verarbeite Datei: ./9_595_mpnn_probs.weights
# Verarbeite Datei: ./5_283_mpnn_probs.weights
# Verarbeite Datei: ./20_599_mpnn_probs.weights
# Verarbeite Datei: ./15_618_mpnn_probs.weights
# Verarbeite Datei: ./0_279_mpnn_probs.weights
# Verarbeite Datei: ./5_57_mpnn_probs.weights
# Verarbeite Datei: ./22_589_mpnn_probs.weights
# Verarbeite Datei: ./16_683_mpnn_probs.weights
# Verarbeite Datei: ./16_363_mpnn_probs.weights
# Verarbeite Datei: ./22_438_mpnn_probs.weights
# Verarbeite Datei: ./5_763_mpnn_probs.weights
# Verarbeite Datei: ./10_113_mpnn_probs.weights
# Verarbeite Datei: ./0_476_mpnn_probs.weights
# Verarbeite Datei: ./22_213_mpnn_probs.weights
# Verarbeite Datei: ./14_894_mpnn_probs.weights
# Verarbeite Datei: ./22_142_mpnn_probs.weights
# Verarbeite Datei: ./22_489_mpnn_probs.weights
# Verarbeite Datei: ./22_168_mpnn_probs.weights
# Verarbeite Datei: ./20_739_mpnn_probs.weights
# Verarbeite Datei: ./13_298_mpnn_probs.weights
# Verarbeite Datei: ./9_578_mpnn_probs.weights
# Verarbeite Datei: ./5_553_mpnn_probs.weights
# Verarbeite Datei: ./16_780_mpnn_probs.weights
# Verarbeite Datei: ./16_195_mpnn_probs.weights
# Verarbeite Datei: ./14_797_mpnn_probs.weights
# Verarbeite Datei: ./5_726_mpnn_probs.weights
# Verarbeite Datei: ./9_214_mpnn_probs.weights
# Verarbeite Datei: ./14_480_mpnn_probs.weights
# Verarbeite Datei: ./9_522_mpnn_probs.weights
# Verarbeite Datei: ./20_881_mpnn_probs.weights
# Verarbeite Datei: ./13_919_mpnn_probs.weights
# Verarbeite Datei: ./22_976_mpnn_probs.weights
# Verarbeite Datei: ./20_459_mpnn_probs.weights
# Verarbeite Datei: ./16_277_mpnn_probs.weights
# Verarbeite Datei: ./0_35_mpnn_probs.weights
# Verarbeite Datei: ./16_980_mpnn_probs.weights
# Verarbeite Datei: ./9_299_mpnn_probs.weights
# Verarbeite Datei: ./15_977_mpnn_probs.weights
# Verarbeite Datei: ./9_1000_mpnn_probs.weights
# Verarbeite Datei: ./13_141_mpnn_probs.weights
# Verarbeite Datei: ./13_880_mpnn_probs.weights
# Verarbeite Datei: ./0_458_mpnn_probs.weights
# Verarbeite Datei: ./14_633_mpnn_probs.weights
# Verarbeite Datei: ./9_799_mpnn_probs.weights
# Verarbeite Datei: ./5_242_mpnn_probs.weights
# Verarbeite Datei: ./9_250_mpnn_probs.weights
# Verarbeite Datei: ./5_713_mpnn_probs.weights
# Verarbeite Datei: ./15_383_mpnn_probs.weights
# Verarbeite Datei: ./5_920_mpnn_probs.weights
# Verarbeite Datei: ./13_197_mpnn_probs.weights
# Verarbeite Datei: ./0_273_mpnn_probs.weights
# Verarbeite Datei: ./16_100_mpnn_probs.weights
# Verarbeite Datei: ./15_134_mpnn_probs.weights
# Verarbeite Datei: ./13_135_mpnn_probs.weights
# Verarbeite Datei: ./15_939_mpnn_probs.weights
# Verarbeite Datei: ./22_848_mpnn_probs.weights
# Verarbeite Datei: ./9_364_mpnn_probs.weights
# Verarbeite Datei: ./14_863_mpnn_probs.weights
# Verarbeite Datei: ./20_955_mpnn_probs.weights
# Verarbeite Datei: ./13_576_mpnn_probs.weights
# Verarbeite Datei: ./0_549_mpnn_probs.weights
# Verarbeite Datei: ./5_729_mpnn_probs.weights
# Verarbeite Datei: ./13_66_mpnn_probs.weights
# Verarbeite Datei: ./16_310_mpnn_probs.weights
# Verarbeite Datei: ./14_845_mpnn_probs.weights
# Verarbeite Datei: ./5_277_mpnn_probs.weights
# Verarbeite Datei: ./10_121_mpnn_probs.weights
# Verarbeite Datei: ./5_14_mpnn_probs.weights
# Verarbeite Datei: ./16_261_mpnn_probs.weights
# Verarbeite Datei: ./13_1_mpnn_probs.weights
# Verarbeite Datei: ./9_157_mpnn_probs.weights
# Verarbeite Datei: ./10_365_mpnn_probs.weights
# Verarbeite Datei: ./13_978_mpnn_probs.weights
# Verarbeite Datei: ./13_332_mpnn_probs.weights
# Verarbeite Datei: ./16_746_mpnn_probs.weights
# Verarbeite Datei: ./9_911_mpnn_probs.weights
# Verarbeite Datei: ./14_780_mpnn_probs.weights
# Verarbeite Datei: ./10_736_mpnn_probs.weights
# Verarbeite Datei: ./5_72_mpnn_probs.weights
# Verarbeite Datei: ./16_571_mpnn_probs.weights
# Verarbeite Datei: ./15_911_mpnn_probs.weights
# Verarbeite Datei: ./20_401_mpnn_probs.weights
# Verarbeite Datei: ./15_979_mpnn_probs.weights
# Verarbeite Datei: ./5_847_mpnn_probs.weights
# Verarbeite Datei: ./0_154_mpnn_probs.weights
# Verarbeite Datei: ./20_30_mpnn_probs.weights
# Verarbeite Datei: ./20_603_mpnn_probs.weights
# Verarbeite Datei: ./22_355_mpnn_probs.weights
# Verarbeite Datei: ./0_2_mpnn_probs.weights
# Verarbeite Datei: ./9_225_mpnn_probs.weights
# Verarbeite Datei: ./10_848_mpnn_probs.weights
# Verarbeite Datei: ./22_357_mpnn_probs.weights
# Verarbeite Datei: ./0_326_mpnn_probs.weights
# Verarbeite Datei: ./9_483_mpnn_probs.weights
# Verarbeite Datei: ./15_139_mpnn_probs.weights
# Verarbeite Datei: ./14_619_mpnn_probs.weights
# Verarbeite Datei: ./22_81_mpnn_probs.weights
# Verarbeite Datei: ./5_962_mpnn_probs.weights
# Verarbeite Datei: ./16_954_mpnn_probs.weights
# Verarbeite Datei: ./10_125_mpnn_probs.weights
# Verarbeite Datei: ./15_728_mpnn_probs.weights
# Verarbeite Datei: ./16_905_mpnn_probs.weights
# Verarbeite Datei: ./14_551_mpnn_probs.weights
# Verarbeite Datei: ./9_260_mpnn_probs.weights
# Verarbeite Datei: ./13_374_mpnn_probs.weights
# Verarbeite Datei: ./14_515_mpnn_probs.weights
# Verarbeite Datei: ./9_525_mpnn_probs.weights
# Verarbeite Datei: ./16_845_mpnn_probs.weights
# Verarbeite Datei: ./13_456_mpnn_probs.weights
# Verarbeite Datei: ./0_798_mpnn_probs.weights
# Verarbeite Datei: ./13_486_mpnn_probs.weights
# Verarbeite Datei: ./0_567_mpnn_probs.weights
# Verarbeite Datei: ./16_838_mpnn_probs.weights
# Verarbeite Datei: ./0_512_mpnn_probs.weights
# Verarbeite Datei: ./16_528_mpnn_probs.weights
# Verarbeite Datei: ./14_13_mpnn_probs.weights
# Verarbeite Datei: ./22_741_mpnn_probs.weights
# Verarbeite Datei: ./20_395_mpnn_probs.weights
# Verarbeite Datei: ./13_750_mpnn_probs.weights
# Verarbeite Datei: ./16_427_mpnn_probs.weights
# Verarbeite Datei: ./9_208_mpnn_probs.weights
# Verarbeite Datei: ./9_371_mpnn_probs.weights
# Verarbeite Datei: ./0_159_mpnn_probs.weights
# Verarbeite Datei: ./5_108_mpnn_probs.weights
# Verarbeite Datei: ./20_813_mpnn_probs.weights
# Verarbeite Datei: ./10_959_mpnn_probs.weights
# Verarbeite Datei: ./20_683_mpnn_probs.weights
# Verarbeite Datei: ./22_481_mpnn_probs.weights
# Verarbeite Datei: ./16_58_mpnn_probs.weights
# Verarbeite Datei: ./22_961_mpnn_probs.weights
# Verarbeite Datei: ./22_628_mpnn_probs.weights
# Verarbeite Datei: ./5_119_mpnn_probs.weights
# Verarbeite Datei: ./5_899_mpnn_probs.weights
# Verarbeite Datei: ./0_184_mpnn_probs.weights
# Verarbeite Datei: ./5_105_mpnn_probs.weights
# Verarbeite Datei: ./15_509_mpnn_probs.weights
# Verarbeite Datei: ./13_156_mpnn_probs.weights
# Verarbeite Datei: ./16_702_mpnn_probs.weights
# Verarbeite Datei: ./16_229_mpnn_probs.weights
# Verarbeite Datei: ./16_19_mpnn_probs.weights
# Verarbeite Datei: ./9_909_mpnn_probs.weights
# Verarbeite Datei: ./16_489_mpnn_probs.weights
# Verarbeite Datei: ./15_615_mpnn_probs.weights
# Verarbeite Datei: ./16_598_mpnn_probs.weights
# Verarbeite Datei: ./5_567_mpnn_probs.weights
# Verarbeite Datei: ./22_7_mpnn_probs.weights
# Verarbeite Datei: ./20_17_mpnn_probs.weights
# Verarbeite Datei: ./16_163_mpnn_probs.weights
# Verarbeite Datei: ./0_772_mpnn_probs.weights
# Verarbeite Datei: ./0_196_mpnn_probs.weights
# Verarbeite Datei: ./15_60_mpnn_probs.weights
# Verarbeite Datei: ./15_219_mpnn_probs.weights
# Verarbeite Datei: ./13_980_mpnn_probs.weights
# Verarbeite Datei: ./5_997_mpnn_probs.weights
# Verarbeite Datei: ./0_364_mpnn_probs.weights
# Verarbeite Datei: ./20_202_mpnn_probs.weights
# Verarbeite Datei: ./20_559_mpnn_probs.weights
# Verarbeite Datei: ./5_55_mpnn_probs.weights
# Verarbeite Datei: ./22_299_mpnn_probs.weights
# Verarbeite Datei: ./13_325_mpnn_probs.weights
# Verarbeite Datei: ./15_132_mpnn_probs.weights
# Verarbeite Datei: ./0_818_mpnn_probs.weights
# Verarbeite Datei: ./9_34_mpnn_probs.weights
# Verarbeite Datei: ./10_758_mpnn_probs.weights
# Verarbeite Datei: ./13_876_mpnn_probs.weights
# Verarbeite Datei: ./15_348_mpnn_probs.weights
# Verarbeite Datei: ./0_727_mpnn_probs.weights
# Verarbeite Datei: ./20_74_mpnn_probs.weights
# Verarbeite Datei: ./20_674_mpnn_probs.weights
# Verarbeite Datei: ./5_258_mpnn_probs.weights
# Verarbeite Datei: ./20_489_mpnn_probs.weights
# Verarbeite Datei: ./9_551_mpnn_probs.weights
# Verarbeite Datei: ./5_736_mpnn_probs.weights
# Verarbeite Datei: ./20_468_mpnn_probs.weights
# Verarbeite Datei: ./9_912_mpnn_probs.weights
# Verarbeite Datei: ./15_713_mpnn_probs.weights
# Verarbeite Datei: ./9_479_mpnn_probs.weights
# Verarbeite Datei: ./14_719_mpnn_probs.weights
# Verarbeite Datei: ./14_533_mpnn_probs.weights
# Verarbeite Datei: ./5_77_mpnn_probs.weights
# Verarbeite Datei: ./5_274_mpnn_probs.weights
# Verarbeite Datei: ./5_810_mpnn_probs.weights
# Verarbeite Datei: ./0_581_mpnn_probs.weights
# Verarbeite Datei: ./14_706_mpnn_probs.weights
# Verarbeite Datei: ./16_238_mpnn_probs.weights
# Verarbeite Datei: ./14_186_mpnn_probs.weights
# Verarbeite Datei: ./5_867_mpnn_probs.weights
# Verarbeite Datei: ./16_453_mpnn_probs.weights
# Verarbeite Datei: ./22_175_mpnn_probs.weights
# Verarbeite Datei: ./5_168_mpnn_probs.weights
# Verarbeite Datei: ./13_91_mpnn_probs.weights
# Verarbeite Datei: ./20_231_mpnn_probs.weights
# Verarbeite Datei: ./16_552_mpnn_probs.weights
# Verarbeite Datei: ./9_392_mpnn_probs.weights
# Verarbeite Datei: ./5_470_mpnn_probs.weights
# Verarbeite Datei: ./13_287_mpnn_probs.weights
# Verarbeite Datei: ./16_256_mpnn_probs.weights
# Verarbeite Datei: ./16_411_mpnn_probs.weights
# Verarbeite Datei: ./22_115_mpnn_probs.weights
# Verarbeite Datei: ./15_873_mpnn_probs.weights
# Verarbeite Datei: ./0_692_mpnn_probs.weights
# Verarbeite Datei: ./0_845_mpnn_probs.weights
# Verarbeite Datei: ./15_464_mpnn_probs.weights
# Verarbeite Datei: ./15_789_mpnn_probs.weights
# Verarbeite Datei: ./9_116_mpnn_probs.weights
# Verarbeite Datei: ./16_226_mpnn_probs.weights
# Verarbeite Datei: ./22_771_mpnn_probs.weights
# Verarbeite Datei: ./16_303_mpnn_probs.weights
# Verarbeite Datei: ./14_22_mpnn_probs.weights
# Verarbeite Datei: ./9_236_mpnn_probs.weights
# Verarbeite Datei: ./15_985_mpnn_probs.weights
# Verarbeite Datei: ./14_556_mpnn_probs.weights
# Verarbeite Datei: ./13_166_mpnn_probs.weights
# Verarbeite Datei: ./15_619_mpnn_probs.weights
# Verarbeite Datei: ./13_217_mpnn_probs.weights
# Verarbeite Datei: ./16_706_mpnn_probs.weights
# Verarbeite Datei: ./10_773_mpnn_probs.weights
# Verarbeite Datei: ./22_446_mpnn_probs.weights
# Verarbeite Datei: ./20_903_mpnn_probs.weights
# Verarbeite Datei: ./22_829_mpnn_probs.weights
# Verarbeite Datei: ./16_250_mpnn_probs.weights
# Verarbeite Datei: ./13_72_mpnn_probs.weights
# Verarbeite Datei: ./14_646_mpnn_probs.weights
# Verarbeite Datei: ./16_233_mpnn_probs.weights
# Verarbeite Datei: ./10_172_mpnn_probs.weights
# Verarbeite Datei: ./16_448_mpnn_probs.weights
# Verarbeite Datei: ./22_256_mpnn_probs.weights
# Verarbeite Datei: ./9_948_mpnn_probs.weights
# Verarbeite Datei: ./9_991_mpnn_probs.weights
# Verarbeite Datei: ./13_129_mpnn_probs.weights
# Verarbeite Datei: ./0_732_mpnn_probs.weights
# Verarbeite Datei: ./5_218_mpnn_probs.weights
# Verarbeite Datei: ./16_763_mpnn_probs.weights
# Verarbeite Datei: ./22_326_mpnn_probs.weights
# Verarbeite Datei: ./22_711_mpnn_probs.weights
# Verarbeite Datei: ./10_585_mpnn_probs.weights
# Verarbeite Datei: ./13_453_mpnn_probs.weights
# Verarbeite Datei: ./13_230_mpnn_probs.weights
# Verarbeite Datei: ./22_940_mpnn_probs.weights
# Verarbeite Datei: ./5_199_mpnn_probs.weights
# Verarbeite Datei: ./10_549_mpnn_probs.weights
# Verarbeite Datei: ./20_560_mpnn_probs.weights
# Verarbeite Datei: ./14_776_mpnn_probs.weights
# Verarbeite Datei: ./13_965_mpnn_probs.weights
# Verarbeite Datei: ./10_515_mpnn_probs.weights
# Verarbeite Datei: ./5_73_mpnn_probs.weights
# Verarbeite Datei: ./16_923_mpnn_probs.weights
# Verarbeite Datei: ./14_37_mpnn_probs.weights
# Verarbeite Datei: ./13_597_mpnn_probs.weights
# Verarbeite Datei: ./10_180_mpnn_probs.weights
# Verarbeite Datei: ./9_710_mpnn_probs.weights
# Verarbeite Datei: ./20_723_mpnn_probs.weights
# Verarbeite Datei: ./9_196_mpnn_probs.weights
# Verarbeite Datei: ./9_215_mpnn_probs.weights
# Verarbeite Datei: ./13_986_mpnn_probs.weights
# Verarbeite Datei: ./15_902_mpnn_probs.weights
# Verarbeite Datei: ./15_291_mpnn_probs.weights
# Verarbeite Datei: ./5_387_mpnn_probs.weights
# Verarbeite Datei: ./20_471_mpnn_probs.weights
# Verarbeite Datei: ./13_586_mpnn_probs.weights
# Verarbeite Datei: ./5_803_mpnn_probs.weights
# Verarbeite Datei: ./9_112_mpnn_probs.weights
# Verarbeite Datei: ./5_34_mpnn_probs.weights
# Verarbeite Datei: ./15_955_mpnn_probs.weights
# Verarbeite Datei: ./10_934_mpnn_probs.weights
# Verarbeite Datei: ./16_91_mpnn_probs.weights
# Verarbeite Datei: ./0_460_mpnn_probs.weights
# Verarbeite Datei: ./9_470_mpnn_probs.weights
# Verarbeite Datei: ./0_970_mpnn_probs.weights
# Verarbeite Datei: ./14_798_mpnn_probs.weights
# Verarbeite Datei: ./5_63_mpnn_probs.weights
# Verarbeite Datei: ./15_69_mpnn_probs.weights
# Verarbeite Datei: ./15_742_mpnn_probs.weights
# Verarbeite Datei: ./16_225_mpnn_probs.weights
# Verarbeite Datei: ./10_932_mpnn_probs.weights
# Verarbeite Datei: ./16_32_mpnn_probs.weights
# Verarbeite Datei: ./14_250_mpnn_probs.weights
# Verarbeite Datei: ./0_627_mpnn_probs.weights
# Verarbeite Datei: ./14_625_mpnn_probs.weights
# Verarbeite Datei: ./16_707_mpnn_probs.weights
# Verarbeite Datei: ./10_643_mpnn_probs.weights
# Verarbeite Datei: ./15_40_mpnn_probs.weights
# Verarbeite Datei: ./16_117_mpnn_probs.weights
# Verarbeite Datei: ./0_666_mpnn_probs.weights
# Verarbeite Datei: ./20_469_mpnn_probs.weights
# Verarbeite Datei: ./10_301_mpnn_probs.weights
# Verarbeite Datei: ./13_488_mpnn_probs.weights
# Verarbeite Datei: ./9_828_mpnn_probs.weights
# Verarbeite Datei: ./15_894_mpnn_probs.weights
# Verarbeite Datei: ./16_582_mpnn_probs.weights
# Verarbeite Datei: ./9_680_mpnn_probs.weights
# Verarbeite Datei: ./10_539_mpnn_probs.weights
# Verarbeite Datei: ./20_36_mpnn_probs.weights
# Verarbeite Datei: ./13_961_mpnn_probs.weights
# Verarbeite Datei: ./14_359_mpnn_probs.weights
# Verarbeite Datei: ./16_912_mpnn_probs.weights
# Verarbeite Datei: ./20_62_mpnn_probs.weights
# Verarbeite Datei: ./16_804_mpnn_probs.weights
# Verarbeite Datei: ./16_126_mpnn_probs.weights
# Verarbeite Datei: ./16_800_mpnn_probs.weights
# Verarbeite Datei: ./5_201_mpnn_probs.weights
# Verarbeite Datei: ./9_639_mpnn_probs.weights
# Verarbeite Datei: ./0_574_mpnn_probs.weights
# Verarbeite Datei: ./15_895_mpnn_probs.weights
# Die durchschnittlichen Gewichte wurden in './mpnn_probs.weights' gespeichert.
